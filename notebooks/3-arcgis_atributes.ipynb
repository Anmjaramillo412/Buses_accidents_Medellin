# %% [markdown]
# ## Análisis de accidentes - Buses
#
# ### Area metropolitana del Valle de Aburrá
#
# Manuela Cordoba
#
# Alejandro Fernandez
#
# Ana María Jaramillo

# %%
import pandas as pd
import config

# %%
more_attributes = pd.read_excel(config.ADDITIONAL_ATRIBUTES)
more_attributes
# Out:
#        OBJECTID  Join_Count  TARGET_FID  Join_Count_1  TARGET_FID_1  \
# 0             1           7           0             1             1
# 1             2           3           1             1             2
# 2             3           3           2             1             3
# 3             4           5           3             1             4
# 4             5           4           4             1             5
# ...         ...         ...         ...           ...           ...
# 45558     45559           3       45558             1         45559
# 45559     45560           6       45559             1         45560
# 45560     45561           4       45560             1         45561
# 45561     45562           5       45561             1         45562
# 45562     45563           3       45562             1         45563
#
#        Join_Count_12  TARGET_FID_12  Join_Count_12_13  TARGET_FID_12_13  \
# 0                  3              1                 1                 1
# ...

# %%
print(more_attributes.columns)
# Out:
# Index(['OBJECTID', 'Join_Count', 'TARGET_FID', 'Join_Count_1', 'TARGET_FID_1',
#        'Join_Count_12', 'TARGET_FID_12', 'Join_Count_12_13',
#        'TARGET_FID_12_13', 'RADICADO', 'HORA', 'DIA_NOMBRE', 'PERIODO',
#        'CLASE', 'DIRECCION', 'DIRECCION_', 'CBML', 'TIPO_GEOCO', 'GRAVEDAD',
#        'BARRIO', 'COMUNA', 'DISENO', 'MES', 'DIA', 'FECHA', 'MES_NOMBRE',
#        'X_MAGNAMED', 'Y_MAGNAMED', 'LONGITUD', 'LATITUD', 'areagralus',
#        'cod_cat_us', 'cod_subcat', 'subcategor', 'CODIGO', 'NOMBRE',
#        'ABREVIATURA', 'LIMITECOMUNACORREGIMIENTOID', 'SUBTIPO_BARRIOVEREDA',
#        'FULL_STREE', 'HIERARCHY', 'ROAD_CLASS', 'ESTRATO_PR'],
#       dtype='object')

# %%
more_attributes.drop(
    columns=[
        "OBJECTID",
        "Join_Count",
        "TARGET_FID",
        "Join_Count_1",
        "TARGET_FID_1",
        "Join_Count_12",
        "TARGET_FID_12",
        "Join_Count_12_13",
        "TARGET_FID_12_13",
        "DIRECCION_",
        "CBML",
        "CODIGO",
        "ABREVIATURA",
        "LIMITECOMUNACORREGIMIENTOID",
        "SUBTIPO_BARRIOVEREDA",
        "DIA_NOMBRE",
        "MES_NOMBRE",
        "X_MAGNAMED",
        "Y_MAGNAMED",
        "FECHA",
        "NOMBRE",
        "DIRECCION",
        "FULL_STREE",
    ],
    inplace=True,
)
more_attributes
# Out:
#        RADICADO           HORA  PERIODO           CLASE  \
# 0       1739400  2:20:00 p. m.     2021  Caida Ocupante
# 1       1735512  6:20:00 p. m.     2021          Choque
# 2       1735374  7:30:00 p. m.     2021          Choque
# 3       1735813  6:40:00 p. m.     2021          Choque
# 4       1736179  3:30:00 p. m.     2021          Choque
# ...         ...            ...      ...             ...
# 45558   1470953       10:50 AM     2014          Choque
# 45559   1470975       01:30 PM     2014          Choque
# 45560   1470979       04:50 PM     2014          Choque
# 45561   1470984       01:10 PM     2014          Choque
# 45562   1470985       03:20 PM     2014          Choque
#
#                             TIPO_GEOCO     GRAVEDAD                BARRIO  \
# 0                           Malla vial  CON HERIDOS                 Prado
# 1                           Malla vial   SOLO DAÑOS           El Progreso
# ...

# %%
more_attributes.to_excel(config.ATRIBUTOS_GEOREFERENCIADOS, index=False)
